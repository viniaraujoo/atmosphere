# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt
import sklearn
import os
import shap
import keras.backend as K
from keras.applications.vgg16 import preprocess_input
from keras.models import load_model
from keras.metrics import top_k_categorical_accuracy
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from skimage.segmentation import mark_boundaries
# Display
from IPython.display import Image
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def top_2_accuracy(in_gt, in_pred):
    return top_k_categorical_accuracy(in_gt, in_pred, k=2)
model = load_model('retinopathy_diabetic/model/full_retina_model.h5',custom_objects={'top_2_accuracy': top_2_accuracy})
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py:304: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
def transform_img_fn(path_list):
    '''Transform image so it can be processed by inception.'''
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=(512, 512))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = inc_net.preprocess_input(x)
        out.append(x)
    return np.vstack(out)

# %%
base_image_dir = os.path.join('retinopathy_diabetic', 'figure')
retina_df = pd.read_csv(os.path.join(base_image_dir, 'trainLabels.csv'))
retina_df['PatientId'] = retina_df['image'].map(lambda x: x.split('_')[0])
retina_df['path'] = retina_df['image'].map(lambda x: os.path.join(base_image_dir,
                                                         '{}.jpeg'.format(x)))

# %%
retina_df
# Out:
#              image  level PatientId  \
# 0          10_left      0        10
# 1         10_right      0        10
# 2          13_left      0        13
# 3         13_right      0        13
# 4          15_left      1        15
# 5         15_right      2        15
# 6          16_left      4        16
# 7         16_right      4        16
# 8          17_left      0        17
# 9         17_right      1        17
# 10         19_left      0        19
# 11        19_right      0        19
# 12         20_left      0        20
# 13        20_right      0        20
# 14         21_left      0        21
# 15        21_right      0        21
# 16         22_left      0        22
# 17        22_right      0        22
# 18         23_left      0        23
# 19        23_right      0        23
# 20         25_left      0        25
# 21        25_right      0        25
# 22         30_left      1        30
# 23        30_right      2        30
# 24         31_left      0        31
# 25        31_right      0        31
# 26         33_left      0        33
# 27        33_right      0        33
# 28         36_left      1        36
# 29        36_right      0        36
# ...            ...    ...       ...
# 35096   44317_left      0     44317
# 35097  44317_right      0     44317
# 35098   44323_left      1     44323
# 35099  44323_right      1     44323
# 35100   44325_left      0     44325
# 35101  44325_right      0     44325
# 35102   44327_left      0     44327
# 35103  44327_right      0     44327
# 35104   44328_left      0     44328
# 35105  44328_right      1     44328
# 35106   44330_left      0     44330
# 35107  44330_right      0     44330
# 35108   44331_left      0     44331
# 35109  44331_right      0     44331
# 35110   44334_left      0     44334
# 35111  44334_right      0     44334
# 35112   44337_left      1     44337
# 35113  44337_right      0     44337
# 35114   44338_left      0     44338
# 35115  44338_right      0     44338
# 35116   44339_left      0     44339
# 35117  44339_right      0     44339
# 35118   44343_left      0     44343
# 35119  44343_right      0     44343
# 35120   44347_left      0     44347
# 35121  44347_right      0     44347
# 35122   44348_left      0     44348
# 35123  44348_right      0     44348
# 35124   44349_left      0     44349
# 35125  44349_right      1     44349
#
#                                                path
# 0          retinopathy_diabetic/figure/10_left.jpeg
# 1         retinopathy_diabetic/figure/10_right.jpeg
# 2          retinopathy_diabetic/figure/13_left.jpeg
# 3         retinopathy_diabetic/figure/13_right.jpeg
# 4          retinopathy_diabetic/figure/15_left.jpeg
# 5         retinopathy_diabetic/figure/15_right.jpeg
# 6          retinopathy_diabetic/figure/16_left.jpeg
# 7         retinopathy_diabetic/figure/16_right.jpeg
# 8          retinopathy_diabetic/figure/17_left.jpeg
# 9         retinopathy_diabetic/figure/17_right.jpeg
# 10         retinopathy_diabetic/figure/19_left.jpeg
# 11        retinopathy_diabetic/figure/19_right.jpeg
# 12         retinopathy_diabetic/figure/20_left.jpeg
# 13        retinopathy_diabetic/figure/20_right.jpeg
# 14         retinopathy_diabetic/figure/21_left.jpeg
# 15        retinopathy_diabetic/figure/21_right.jpeg
# 16         retinopathy_diabetic/figure/22_left.jpeg
# 17        retinopathy_diabetic/figure/22_right.jpeg
# 18         retinopathy_diabetic/figure/23_left.jpeg
# 19        retinopathy_diabetic/figure/23_right.jpeg
# 20         retinopathy_diabetic/figure/25_left.jpeg
# 21        retinopathy_diabetic/figure/25_right.jpeg
# 22         retinopathy_diabetic/figure/30_left.jpeg
# 23        retinopathy_diabetic/figure/30_right.jpeg
# 24         retinopathy_diabetic/figure/31_left.jpeg
# 25        retinopathy_diabetic/figure/31_right.jpeg
# 26         retinopathy_diabetic/figure/33_left.jpeg
# 27        retinopathy_diabetic/figure/33_right.jpeg
# 28         retinopathy_diabetic/figure/36_left.jpeg
# 29        retinopathy_diabetic/figure/36_right.jpeg
# ...                                             ...
# 35096   retinopathy_diabetic/figure/44317_left.jpeg
# 35097  retinopathy_diabetic/figure/44317_right.jpeg
# 35098   retinopathy_diabetic/figure/44323_left.jpeg
# 35099  retinopathy_diabetic/figure/44323_right.jpeg
# 35100   retinopathy_diabetic/figure/44325_left.jpeg
# 35101  retinopathy_diabetic/figure/44325_right.jpeg
# 35102   retinopathy_diabetic/figure/44327_left.jpeg
# 35103  retinopathy_diabetic/figure/44327_right.jpeg
# 35104   retinopathy_diabetic/figure/44328_left.jpeg
# 35105  retinopathy_diabetic/figure/44328_right.jpeg
# 35106   retinopathy_diabetic/figure/44330_left.jpeg
# 35107  retinopathy_diabetic/figure/44330_right.jpeg
# 35108   retinopathy_diabetic/figure/44331_left.jpeg
# 35109  retinopathy_diabetic/figure/44331_right.jpeg
# 35110   retinopathy_diabetic/figure/44334_left.jpeg
# 35111  retinopathy_diabetic/figure/44334_right.jpeg
# 35112   retinopathy_diabetic/figure/44337_left.jpeg
# 35113  retinopathy_diabetic/figure/44337_right.jpeg
# 35114   retinopathy_diabetic/figure/44338_left.jpeg
# 35115  retinopathy_diabetic/figure/44338_right.jpeg
# 35116   retinopathy_diabetic/figure/44339_left.jpeg
# 35117  retinopathy_diabetic/figure/44339_right.jpeg
# 35118   retinopathy_diabetic/figure/44343_left.jpeg
# 35119  retinopathy_diabetic/figure/44343_right.jpeg
# 35120   retinopathy_diabetic/figure/44347_left.jpeg
# 35121  retinopathy_diabetic/figure/44347_right.jpeg
# 35122   retinopathy_diabetic/figure/44348_left.jpeg
# 35123  retinopathy_diabetic/figure/44348_right.jpeg
# 35124   retinopathy_diabetic/figure/44349_left.jpeg
# 35125  retinopathy_diabetic/figure/44349_right.jpeg
#
# [35126 rows x 4 columns]

# %%
amostra = np.ndarray(shape=(5, 512, 512,3),
                     dtype=np.float32)

# %%
to_explain = retina_df['path'][19]

# %%
to_explain
# Out:
# 'retinopathy_diabetic/figure/23_right.jpeg'

# %%
amostra[0] = transform_img_fn([''])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-0f9144e2e5be> in <module>()
# ----> 1 amostra[0] = transform_img_fn([retina_df['path'][18]])
#
# <ipython-input-5-4fd2614aab95> in transform_img_fn(path_list)
#       3     out = []
#       4     for img_path in path_list:
# ----> 5         img = image.load_img(img_path, target_size=(512, 512))
#       6         x = image.img_to_array(img)
#       7         x = np.expand_dims(x, axis=0)
#
# ~/.local/lib/python3.6/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     102         raise ImportError('Could not import PIL.Image. '
#     103                           'The use of `array_to_img` requires PIL.')
# --> 104     img = pil_image.open(path)
#     105     if color_mode == 'grayscale':
#     106         if img.mode != 'L':
#
# /anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2541
#    2542     if filename:
# -> 2543         fp = builtins.open(filename, "rb")
#    2544         exclusive_fp = True
#    2545
#
# FileNotFoundError: [Errno 2] No such file or directory: 'retinopathy_diabetic/figure/23_left.jpeg'
